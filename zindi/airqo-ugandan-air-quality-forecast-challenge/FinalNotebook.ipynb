# %% [markdown]
# ## Only for Colab users
#
# To get this to run on colab. Click on the badge.
#
#
# {{ badge }}
#
# Also the script is set up to get the needed files from the repo and also performs the installation of the scripts [dependencies](https://github.com/mnm-rnd/competitions/blob/master/zindi/airqo-ugandan-air-quality-forecast-challenge/requirements.txt)

# %%
# !git clone https://github.com/mnm-rnd/competitions.git

# !mv ./competitions/zindi/airqo-ugandan-air-quality-forecast-challenge/mlod ./mlod
# !pip install ./competitions/zindi/airqo-ugandan-air-quality-forecast-challenge/mlod/requirements.txt

# !rm -rf ./competitions

# %% [markdown]
# # AirQo Ugandan Air Quality Forecast Challenge
#
# This notebook contains the reformat of the code, so that properly set up for implementation.
# Most of the code abstractions are written inside our package `mlod`, which should be included with this notebook.

# %% [markdown]
# ## Init Steps
#
# This section involves setting up the data from the `zindi` to use for the competition

# %% [markdown]
# ### Setting up the data
#
# Please upload the to the `./data` path inside the workspace folder. Run the cell below, repeateadly till when there are no errors.
# Make sure the uploaded data is the `Train.csv` and `Test.csv` used in the competition

# %%
from pathlib import Path

train_file_csv = Path('./data/Train.csv')
test_file_csv = Path('./data/Test.csv')

# check if Train file doesn't exist
assert train_file_csv.exists(), 'Make sure the Test csv file exists the path "%s"' % train_file_csv

# check if Test file doesn't exist
assert test_file_csv.exists(), 'Make sure the Test csv file exists the path "%s"' % test_file_csv

# %% [markdown]
# ## Actual sequence of processes

# %% [markdown]
# ### Initiating different processes
#
# Performing steps that are needed for before doing any form of training

# %%
import random
import numpy as np

# using our chosen seed number
from mlod import SEED_NUMBER as MLOD_SEED_NUMBER

# Setting the seed
random.seed(MLOD_SEED_NUMBER)
np.random.seed(MLOD_SEED_NUMBER)

# %% [markdown]
# ### Load and preprocess data

# %%
import pandas as pd

## Fetching the data
train_df = pd.read_csv(train_file_csv)
test_df = pd.read_csv(test_file_csv)

TEST_IDS = test_df['ID']

# %% [markdown]
# ### Preprocessing the data
#
# [Low-level Preprocessing]<br />
# By using the `mlod.preprocessors.*` involves preprocessing the data in the following ways
# - Modifying the data such that each row, has its atomic values, thus making the data **grow** in size
# - Performing **special** feature engineering that some of which include:
#     - Peforming Cyclic Representation to selected features
#     - Using wind speed (`wind_spd`) and direction (`wind_dir`) to obtain
#         catersian values for speed (`u` and `v`)
#     - Add past features within a certain window of an the current row.<br />
#         This technique is to help data make model make relation between sequence of data

# %% [markdown]
# ### Preprocess + Model Training
#
# Since out approach is an ensemble, and the different models are preprocessed differently, the code below, contains the `Model` paired with its `PreProcessor`.
#
# Since for our ensemble we are boosting, we will be using the values from the `1`st process and feed it to the next

# %% [markdown]
# #### 1: LightGBM + Version 1 Pre Processing
#
# This first approach includes using our `MlodPreProcessor` and our `LGBModel`

# %%
from mlod.preprocessors import MlodPreProcessor

mlod_preprocessor = MlodPreProcessor()
mlod_pp_opts = dict(cols_to_retain=['ID'])
x_train, y_train = mlod_preprocessor.process(train_df, **mlod_pp_opts)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 15539/15539 [00:10<00:00, 1415.11it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:11<00:00,  3.88s/it]

# %%
# Training the LGB Model
# ------------------------------
import pandas as pd
from mlod.models import LGBModel
from sklearn.model_selection import GroupKFold

lgb_model = LGBModel('airqo')

# %%
x_train_ids = x_train.pop('ID')
fold_group = x_train['day_idx'].astype(str) + '_' + x_train['24hr_idx'].astype(str)

# %%
assert 'ID' not in x_train.columns, 'Make sure ID is NOT in the columns'

# %%
# perfoming evalution, not training since 'cv' is True
lgb_eval_out = lgb_model.train(x_train, y_train, cv=True, kfold=GroupKFold, group=fold_group, n_splits=3)

# Save the to feed to the next
df_to_feed = pd.DataFrame.from_dict({ 'ID': x_train_ids, 'oof': lgb_eval_out['oof'] })

save_path = './lgb_eval.csv'
df_to_feed.to_csv(save_path)
print('Saving the OOF values to path: {}'.format(save_path))
# Out:
# Training until validation scores don't improve for 1000 rounds
# [2000]	training's rmse: 19.4028	valid_1's rmse: 24.4098
# [4000]	training's rmse: 15.919	valid_1's rmse: 23.4244
# [6000]	training's rmse: 13.8079	valid_1's rmse: 23.0922
# [8000]	training's rmse: 12.3078	valid_1's rmse: 22.9697
# [10000]	training's rmse: 11.2047	valid_1's rmse: 22.9154
# Early stopping, best iteration is:
# [10836]	training's rmse: 10.8278	valid_1's rmse: 22.909
# Training until validation scores don't improve for 1000 rounds
# [2000]	training's rmse: 19.4194	valid_1's rmse: 24.1375
# [4000]	training's rmse: 15.9905	valid_1's rmse: 23.1524
# [6000]	training's rmse: 13.8764	valid_1's rmse: 22.8295
# [8000]	training's rmse: 12.3868	valid_1's rmse: 22.7106
# [10000]	training's rmse: 11.2997	valid_1's rmse: 22.674
# Early stopping, best iteration is:
# [10080]	training's rmse: 11.2594	valid_1's rmse: 22.6723
# Training until validation scores don't improve for 1000 rounds
# [2000]	training's rmse: 19.5012	valid_1's rmse: 24.0629
# [4000]	training's rmse: 16.0247	valid_1's rmse: 23.095
# [6000]	training's rmse: 13.851	valid_1's rmse: 22.7782
# [8000]	training's rmse: 12.348	valid_1's rmse: 22.6734
# [10000]	training's rmse: 11.2388	valid_1's rmse: 22.6508
# Early stopping, best iteration is:
# [10931]	training's rmse: 10.8319	valid_1's rmse: 22.6479
# Saving the OOF values to path: ./lgb_eval.csv

# %%
import lightgbm as lgb

# training the model
lgb_model.train(x_train, y_train, cv=False)

# save the model
lgb_model.model.save_model('./lgb-airqo')

# %% [markdown]
# #### 2: CatBoost + Version 2 Pre Processing
#
# This first approach includes using our `AirQoPreProcessor` and our `CatBoostModel`

# %%
## Training the CatBoost Model
# ------------------------------
from mlod.preprocessors import AirQoPreProcessor

airqo_preprocessor = AirQoPreProcessor()

airqo_pp_opts = dict(cols_to_retain=['ID'])
x_train, y_train = airqo_preprocessor.process(train_df, **airqo_pp_opts)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 121/121 [00:05<00:00, 21.63it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00,  8.68it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:06<00:00,  1.08s/it]

# %%
# since the output of the LGBModel prediction have way more rows (121x) because 
#  of the way it was preprocessed, we need to deal with this
train_feed = df_to_feed.groupby('ID').mean()

# Add the feed value to the data before training to new model
x_train = x_train.join(train_feed, on='ID')

# drop the ID after joining
del x_train['ID']

# %%
from mlod.models import CatBoostModel
from sklearn.model_selection import KFold

cb_model = CatBoostModel('airqo')

# %%
# performing cross validation training
cb_eval_out = cb_model.train(x_train, y_train, cv=True, store_cv_models=True, kfold=KFold, n_splits=50)
# Out:
# 0:	learn: 37.0652628	test: 37.0652628	test1: 40.7618000	best: 40.7618000 (0)	total: 148ms	remaining: 24m 42s
# 20:	learn: 20.1991491	test: 20.1991491	test1: 21.4047649	best: 21.4047649 (20)	total: 1.05s	remaining: 8m 20s
# 40:	learn: 19.3355316	test: 19.3355316	test1: 20.9389828	best: 20.9325021 (35)	total: 1.93s	remaining: 7m 48s
# 60:	learn: 18.5942429	test: 18.5942429	test1: 20.8765409	best: 20.8628185 (50)	total: 2.8s	remaining: 7m 35s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 20.86281845
# bestIteration = 50
#
# Shrink model to first 51 iterations.
# 0:	learn: 37.1597171	test: 37.1597171	test1: 35.5353855	best: 35.5353855 (0)	total: 48.3ms	remaining: 8m 2s
# 20:	learn: 20.2752787	test: 20.2752787	test1: 18.9412098	best: 18.8592769 (18)	total: 932ms	remaining: 7m 22s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 18.85927694
# bestIteration = 18
#
# Shrink model to first 19 iterations.
# 0:	learn: 37.1441632	test: 37.1441632	test1: 35.9132467	best: 35.9132467 (0)	total: 48.2ms	remaining: 8m 1s
# 20:	learn: 20.2187716	test: 20.2187716	test1: 21.8171959	best: 21.7834476 (16)	total: 947ms	remaining: 7m 29s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 21.7834476
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# 0:	learn: 37.2319877	test: 37.2319877	test1: 31.3484075	best: 31.3484075 (0)	total: 48.7ms	remaining: 8m 6s
# 20:	learn: 20.2880423	test: 20.2880423	test1: 19.5804900	best: 19.5262452 (14)	total: 932ms	remaining: 7m 23s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 19.52624525
# bestIteration = 14
#
# Shrink model to first 15 iterations.
# 0:	learn: 37.1573937	test: 37.1573937	test1: 35.9727409	best: 35.9727409 (0)	total: 48.5ms	remaining: 8m 4s
# 20:	learn: 20.3635122	test: 20.3635122	test1: 19.3156513	best: 19.2770832 (18)	total: 926ms	remaining: 7m 20s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 19.27708322
# bestIteration = 18
#
# Shrink model to first 19 iterations.
# 0:	learn: 37.1038679	test: 37.1038679	test1: 38.5861451	best: 38.5861451 (0)	total: 49ms	remaining: 8m 9s
# 20:	learn: 20.2619700	test: 20.2619700	test1: 19.9691885	best: 19.9691885 (20)	total: 930ms	remaining: 7m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 19.91403501
# bestIteration = 21
#
# Shrink model to first 22 iterations.
# 0:	learn: 37.0821173	test: 37.0821173	test1: 39.4898585	best: 39.4898585 (0)	total: 50.5ms	remaining: 8m 25s
# 20:	learn: 20.1634100	test: 20.1634100	test1: 25.8599244	best: 25.7500333 (13)	total: 941ms	remaining: 7m 27s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 25.75003334
# bestIteration = 13
#
# Shrink model to first 14 iterations.
# 0:	learn: 37.1414116	test: 37.1414116	test1: 36.6150109	best: 36.6150109 (0)	total: 50.3ms	remaining: 8m 22s
# 20:	learn: 20.3361761	test: 20.3361761	test1: 20.2835238	best: 20.2835238 (20)	total: 924ms	remaining: 7m 19s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 20.28352379
# bestIteration = 20
#
# Shrink model to first 21 iterations.
# 0:	learn: 37.2216437	test: 37.2216437	test1: 31.7975627	best: 31.7975627 (0)	total: 49.3ms	remaining: 8m 13s
# 20:	learn: 20.2263707	test: 20.2263707	test1: 18.6028206	best: 17.8217448 (11)	total: 931ms	remaining: 7m 22s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 17.82174479
# bestIteration = 11
#
# Shrink model to first 12 iterations.
# 0:	learn: 36.9399315	test: 36.9399315	test1: 45.9601539	best: 45.9601539 (0)	total: 48.5ms	remaining: 8m 5s
# 20:	learn: 20.1428546	test: 20.1428546	test1: 27.1993438	best: 27.1865594 (19)	total: 917ms	remaining: 7m 15s
# 40:	learn: 19.2666766	test: 19.2666766	test1: 27.0719031	best: 26.9568266 (33)	total: 1.78s	remaining: 7m 13s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 26.95682664
# bestIteration = 33
#
# Shrink model to first 34 iterations.
# 0:	learn: 37.0282914	test: 37.0282914	test1: 41.7440140	best: 41.7440140 (0)	total: 48.6ms	remaining: 8m 6s
# 20:	learn: 20.2922308	test: 20.2922308	test1: 22.7112015	best: 22.7112015 (20)	total: 926ms	remaining: 7m 19s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 22.70880908
# bestIteration = 21
#
# Shrink model to first 22 iterations.
# 0:	learn: 37.1655511	test: 37.1655511	test1: 35.4515571	best: 35.4515571 (0)	total: 49.8ms	remaining: 8m 18s
# 20:	learn: 20.3315401	test: 20.3315401	test1: 17.6926495	best: 17.6868687 (18)	total: 936ms	remaining: 7m 24s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 17.61606037
# bestIteration = 24
#
# Shrink model to first 25 iterations.
# 0:	learn: 37.1019502	test: 37.1019502	test1: 38.7600109	best: 38.7600109 (0)	total: 48.1ms	remaining: 8m 1s
# 20:	learn: 20.2186184	test: 20.2186184	test1: 22.6428041	best: 22.5748629 (12)	total: 918ms	remaining: 7m 16s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 22.57486288
# bestIteration = 12
#
# Shrink model to first 13 iterations.
# 0:	learn: 37.1645252	test: 37.1645252	test1: 35.4085984	best: 35.4085984 (0)	total: 49ms	remaining: 8m 9s
# 20:	learn: 20.1497228	test: 20.1497228	test1: 21.3976320	best: 21.3306758 (16)	total: 927ms	remaining: 7m 20s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 21.32264493
# bestIteration = 25
#
# Shrink model to first 26 iterations.
# 0:	learn: 37.2247642	test: 37.2247642	test1: 31.6130990	best: 31.6130990 (0)	total: 48.8ms	remaining: 8m 7s
# 20:	learn: 20.3529999	test: 20.3529999	test1: 17.8358915	best: 17.7947584 (13)	total: 928ms	remaining: 7m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 17.79475841
# bestIteration = 13
#
# Shrink model to first 14 iterations.
# 0:	learn: 37.1567572	test: 37.1567572	test1: 35.3545115	best: 35.3545115 (0)	total: 48.1ms	remaining: 8m 1s
# 20:	learn: 20.2103338	test: 20.2103338	test1: 21.5574756	best: 21.5574756 (20)	total: 925ms	remaining: 7m 19s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 21.54556775
# bestIteration = 21
#
# Shrink model to first 22 iterations.
# 0:	learn: 37.0546550	test: 37.0546550	test1: 40.9282474	best: 40.9282474 (0)	total: 48.8ms	remaining: 8m 7s
# 20:	learn: 20.1710154	test: 20.1710154	test1: 22.9971956	best: 22.9971956 (20)	total: 922ms	remaining: 7m 18s
# 40:	learn: 19.3539146	test: 19.3539146	test1: 22.7092027	best: 22.6919288 (38)	total: 1.8s	remaining: 7m 17s
# 60:	learn: 18.5271174	test: 18.5271174	test1: 22.5605213	best: 22.5524371 (59)	total: 2.67s	remaining: 7m 15s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 22.55027973
# bestIteration = 61
#
# Shrink model to first 62 iterations.
# 0:	learn: 37.1569123	test: 37.1569123	test1: 35.6938558	best: 35.6938558 (0)	total: 48.4ms	remaining: 8m 3s
# 20:	learn: 20.2035575	test: 20.2035575	test1: 20.3388563	best: 20.2567268 (16)	total: 928ms	remaining: 7m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 20.25672677
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# 0:	learn: 37.0613408	test: 37.0613408	test1: 40.6186190	best: 40.6186190 (0)	total: 49.3ms	remaining: 8m 12s
# 20:	learn: 20.3216953	test: 20.3216953	test1: 22.5094052	best: 22.4741613 (15)	total: 919ms	remaining: 7m 16s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 22.47416131
# bestIteration = 15
#
# Shrink model to first 16 iterations.
# 0:	learn: 37.1400297	test: 37.1400297	test1: 36.4993426	best: 36.4993426 (0)	total: 48.8ms	remaining: 8m 7s
# 20:	learn: 20.1640283	test: 20.1640283	test1: 20.9792933	best: 20.9015674 (17)	total: 933ms	remaining: 7m 23s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 20.90156738
# bestIteration = 17
#
# Shrink model to first 18 iterations.
# 0:	learn: 37.1712479	test: 37.1712479	test1: 35.1582876	best: 35.1582876 (0)	total: 48.9ms	remaining: 8m 8s
# 20:	learn: 20.2632294	test: 20.2632294	test1: 19.1146550	best: 19.1146550 (20)	total: 931ms	remaining: 7m 22s
# 40:	learn: 19.3559005	test: 19.3559005	test1: 18.7963320	best: 18.7963320 (40)	total: 1.82s	remaining: 7m 22s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 18.79633199
# bestIteration = 40
#
# Shrink model to first 41 iterations.
# 0:	learn: 37.1695181	test: 37.1695181	test1: 34.7698303	best: 34.7698303 (0)	total: 50.5ms	remaining: 8m 24s
# 20:	learn: 20.2327488	test: 20.2327488	test1: 22.6109705	best: 22.1219692 (11)	total: 950ms	remaining: 7m 31s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 22.12196923
# bestIteration = 11
#
# Shrink model to first 12 iterations.
# 0:	learn: 37.1335544	test: 37.1335544	test1: 36.8851751	best: 36.8851751 (0)	total: 49.7ms	remaining: 8m 16s
# 20:	learn: 20.2916293	test: 20.2916293	test1: 20.0075798	best: 20.0075798 (20)	total: 940ms	remaining: 7m 26s
# 40:	learn: 19.3831669	test: 19.3831669	test1: 19.6600431	best: 19.5336041 (31)	total: 1.81s	remaining: 7m 20s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 19.53360411
# bestIteration = 31
#
# Shrink model to first 32 iterations.
# 0:	learn: 37.1717097	test: 37.1717097	test1: 35.1903696	best: 35.1903696 (0)	total: 50.8ms	remaining: 8m 27s
# 20:	learn: 20.2898749	test: 20.2898749	test1: 17.9010050	best: 17.9010050 (20)	total: 1.06s	remaining: 8m 22s
# 40:	learn: 19.4081700	test: 19.4081700	test1: 17.4273905	best: 17.3452989 (32)	total: 1.98s	remaining: 8m 1s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 17.34529893
# bestIteration = 32
#
# Shrink model to first 33 iterations.
# 0:	learn: 37.1012388	test: 37.1012388	test1: 42.2871838	best: 42.2871838 (0)	total: 65.2ms	remaining: 10m 52s
# 20:	learn: 20.0811780	test: 20.0811780	test1: 26.6211218	best: 26.6211218 (20)	total: 988ms	remaining: 7m 49s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 26.39613188
# bestIteration = 29
#
# Shrink model to first 30 iterations.
# 0:	learn: 37.2425117	test: 37.2425117	test1: 30.5437596	best: 30.5437596 (0)	total: 48.7ms	remaining: 8m 7s
# 20:	learn: 20.2740833	test: 20.2740833	test1: 16.5620018	best: 16.3706555 (15)	total: 943ms	remaining: 7m 28s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 16.37065549
# bestIteration = 15
#
# Shrink model to first 16 iterations.
# 0:	learn: 37.0477917	test: 37.0477917	test1: 41.3191713	best: 41.3191713 (0)	total: 49.8ms	remaining: 8m 17s
# 20:	learn: 20.1842004	test: 20.1842004	test1: 22.0879579	best: 22.0879579 (20)	total: 1.08s	remaining: 8m 34s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 21.96482195
# bestIteration = 26
#
# Shrink model to first 27 iterations.
# 0:	learn: 37.2184283	test: 37.2184283	test1: 32.5705613	best: 32.5705613 (0)	total: 49ms	remaining: 8m 10s
# 20:	learn: 20.2895230	test: 20.2895230	test1: 18.3099856	best: 18.1525075 (15)	total: 943ms	remaining: 7m 28s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 18.15250752
# bestIteration = 15
#
# Shrink model to first 16 iterations.
# 0:	learn: 37.1543530	test: 37.1543530	test1: 35.0648432	best: 35.0648432 (0)	total: 49.1ms	remaining: 8m 10s
# 20:	learn: 20.1000770	test: 20.1000770	test1: 23.4928673	best: 23.3908370 (17)	total: 929ms	remaining: 7m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 23.39083703
# bestIteration = 17
#
# Shrink model to first 18 iterations.
# 0:	learn: 37.1288742	test: 37.1288742	test1: 37.5434732	best: 37.5434732 (0)	total: 49.2ms	remaining: 8m 12s
# 20:	learn: 20.1890350	test: 20.1890350	test1: 18.1111627	best: 18.0881044 (19)	total: 941ms	remaining: 7m 27s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 17.98572086
# bestIteration = 24
#
# Shrink model to first 25 iterations.
# 0:	learn: 37.0693114	test: 37.0693114	test1: 40.4348461	best: 40.4348461 (0)	total: 49.1ms	remaining: 8m 11s
# 20:	learn: 20.2418858	test: 20.2418858	test1: 20.4218740	best: 20.4218740 (20)	total: 930ms	remaining: 7m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 20.16544625
# bestIteration = 25
#
# Shrink model to first 26 iterations.
# 0:	learn: 37.1582500	test: 37.1582500	test1: 35.5636955	best: 35.5636955 (0)	total: 50ms	remaining: 8m 20s
# 20:	learn: 20.2314771	test: 20.2314771	test1: 20.2287998	best: 20.2287998 (20)	total: 929ms	remaining: 7m 21s
# 40:	learn: 19.3697400	test: 19.3697400	test1: 20.0303569	best: 20.0068550 (36)	total: 1.81s	remaining: 7m 19s
# 60:	learn: 18.6588528	test: 18.6588528	test1: 20.2716218	best: 20.0058250 (53)	total: 2.68s	remaining: 7m 16s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 20.00582495
# bestIteration = 53
#
# Shrink model to first 54 iterations.
# 0:	learn: 37.0453925	test: 37.0453925	test1: 41.4620470	best: 41.4620470 (0)	total: 51.8ms	remaining: 8m 38s
# 20:	learn: 20.2421478	test: 20.2421478	test1: 21.1820086	best: 21.1820086 (20)	total: 929ms	remaining: 7m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 21.1625874
# bestIteration = 21
#
# Shrink model to first 22 iterations.
# 0:	learn: 37.1094042	test: 37.1094042	test1: 38.1302560	best: 38.1302560 (0)	total: 48.8ms	remaining: 8m 8s
# 20:	learn: 20.2927240	test: 20.2927240	test1: 20.4614418	best: 19.8112194 (14)	total: 924ms	remaining: 7m 18s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 19.81121939
# bestIteration = 14
#
# Shrink model to first 15 iterations.
# 0:	learn: 37.1803842	test: 37.1803842	test1: 34.0800123	best: 34.0800123 (0)	total: 50.9ms	remaining: 8m 28s
# 20:	learn: 20.2033340	test: 20.2033340	test1: 19.4149730	best: 19.2839406 (16)	total: 938ms	remaining: 7m 25s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 19.28394063
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# 0:	learn: 36.9865490	test: 36.9865490	test1: 44.0088167	best: 44.0088167 (0)	total: 49.4ms	remaining: 8m 13s
# 20:	learn: 20.1063759	test: 20.1063759	test1: 23.8513709	best: 23.8226087 (18)	total: 940ms	remaining: 7m 26s
# 40:	learn: 19.2520413	test: 19.2520413	test1: 23.1485945	best: 23.1485945 (40)	total: 1.81s	remaining: 7m 20s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 23.14859446
# bestIteration = 40
#
# Shrink model to first 41 iterations.
# 0:	learn: 37.1409374	test: 37.1409374	test1: 36.4794042	best: 36.4794042 (0)	total: 61ms	remaining: 10m 10s
# 20:	learn: 20.2723677	test: 20.2723677	test1: 18.9737441	best: 18.9737441 (20)	total: 945ms	remaining: 7m 28s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 18.8995141
# bestIteration = 25
#
# Shrink model to first 26 iterations.
# 0:	learn: 37.1453034	test: 37.1453034	test1: 35.6502214	best: 35.6502214 (0)	total: 49ms	remaining: 8m 10s
# 20:	learn: 20.1776012	test: 20.1776012	test1: 24.0685913	best: 23.6751326 (11)	total: 954ms	remaining: 7m 33s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 23.67513262
# bestIteration = 11
#
# Shrink model to first 12 iterations.
# 0:	learn: 37.2255801	test: 37.2255801	test1: 30.9099667	best: 30.9099667 (0)	total: 48.7ms	remaining: 8m 6s
# 20:	learn: 20.2758521	test: 20.2758521	test1: 18.5023232	best: 18.3562533 (15)	total: 925ms	remaining: 7m 19s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 18.3562533
# bestIteration = 15
#
# Shrink model to first 16 iterations.
# 0:	learn: 37.0695593	test: 37.0695593	test1: 40.3324379	best: 40.3324379 (0)	total: 50.2ms	remaining: 8m 21s
# 20:	learn: 20.1580432	test: 20.1580432	test1: 22.3207260	best: 22.3207260 (20)	total: 929ms	remaining: 7m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 22.27486243
# bestIteration = 24
#
# Shrink model to first 25 iterations.
# 0:	learn: 37.1245533	test: 37.1245533	test1: 37.3503595	best: 37.3503595 (0)	total: 48.9ms	remaining: 8m 9s
# 20:	learn: 20.1122556	test: 20.1122556	test1: 21.7341692	best: 21.7322117 (17)	total: 918ms	remaining: 7m 16s
# 40:	learn: 19.1700771	test: 19.1700771	test1: 21.4432269	best: 21.4382563 (39)	total: 1.8s	remaining: 7m 16s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 21.43825631
# bestIteration = 39
#
# Shrink model to first 40 iterations.
# 0:	learn: 37.1720410	test: 37.1720410	test1: 35.2186652	best: 35.2186652 (0)	total: 49.2ms	remaining: 8m 12s
# 20:	learn: 20.1993295	test: 20.1993295	test1: 20.8603313	best: 20.8591921 (19)	total: 956ms	remaining: 7m 34s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 20.83713266
# bestIteration = 23
#
# Shrink model to first 24 iterations.
# 0:	learn: 37.2008118	test: 37.2008118	test1: 33.4396253	best: 33.4396253 (0)	total: 49.2ms	remaining: 8m 12s
# 20:	learn: 20.2504775	test: 20.2504775	test1: 18.3010825	best: 18.3010825 (20)	total: 932ms	remaining: 7m 22s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 18.16466957
# bestIteration = 26
#
# Shrink model to first 27 iterations.
# 0:	learn: 37.0283546	test: 37.0283546	test1: 42.1950082	best: 42.1950082 (0)	total: 60.4ms	remaining: 10m 3s
# 20:	learn: 20.1135559	test: 20.1135559	test1: 25.0401528	best: 25.0401528 (20)	total: 944ms	remaining: 7m 28s
# 40:	learn: 19.2412487	test: 19.2412487	test1: 24.5574580	best: 24.5342749 (38)	total: 1.82s	remaining: 7m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 24.53427492
# bestIteration = 38
#
# Shrink model to first 39 iterations.
# 0:	learn: 37.1786685	test: 37.1786685	test1: 33.4665283	best: 33.4665283 (0)	total: 49.1ms	remaining: 8m 10s
# 20:	learn: 20.1139064	test: 20.1139064	test1: 22.5273081	best: 21.7687827 (11)	total: 935ms	remaining: 7m 24s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 21.76878266
# bestIteration = 11
#
# Shrink model to first 12 iterations.
# 0:	learn: 37.2106319	test: 37.2106319	test1: 32.4926516	best: 32.4926516 (0)	total: 49.1ms	remaining: 8m 11s
# 20:	learn: 20.2938042	test: 20.2938042	test1: 17.7366108	best: 17.7344143 (15)	total: 933ms	remaining: 7m 23s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 17.7264772
# bestIteration = 21
#
# Shrink model to first 22 iterations.
# 0:	learn: 37.1129125	test: 37.1129125	test1: 37.8103423	best: 37.8103423 (0)	total: 49.6ms	remaining: 8m 16s
# 20:	learn: 20.1397429	test: 20.1397429	test1: 22.7988993	best: 22.7988993 (20)	total: 934ms	remaining: 7m 23s
# 40:	learn: 19.2893787	test: 19.2893787	test1: 22.6542981	best: 22.5599498 (37)	total: 1.82s	remaining: 7m 22s
# 60:	learn: 18.4899327	test: 18.4899327	test1: 22.5105418	best: 22.4733743 (59)	total: 2.7s	remaining: 7m 19s
# 80:	learn: 17.6487953	test: 17.6487953	test1: 22.5642462	best: 22.4284524 (70)	total: 3.6s	remaining: 7m 21s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 22.4284524
# bestIteration = 70
#
# Shrink model to first 71 iterations.
# 0:	learn: 37.1253579	test: 37.1253579	test1: 37.2132461	best: 37.2132461 (0)	total: 49.8ms	remaining: 8m 17s
# 20:	learn: 20.2493037	test: 20.2493037	test1: 19.2877821	best: 19.1453586 (18)	total: 927ms	remaining: 7m 20s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 19.14535862
# bestIteration = 18
#
# Shrink model to first 19 iterations.
# 0:	learn: 37.1638169	test: 37.1638169	test1: 34.9918392	best: 34.9918392 (0)	total: 48.7ms	remaining: 8m 6s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 26.58835564
# bestIteration = 8
#
# Shrink model to first 9 iterations.
# 0:	learn: 36.9967779	test: 36.9967779	test1: 44.1924706	best: 44.1924706 (0)	total: 60.2ms	remaining: 10m 2s
# 20:	learn: 20.2561960	test: 20.2561960	test1: 23.0888601	best: 23.0888601 (20)	total: 953ms	remaining: 7m 33s
# 40:	learn: 19.2697254	test: 19.2697254	test1: 23.1447053	best: 22.6368084 (31)	total: 1.83s	remaining: 7m 24s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 22.63680843
# bestIteration = 31
#
# Shrink model to first 32 iterations.

# %% [markdown]
# ### Ensemble Prediction
#
# Since we are dealing with an ensemble model, the prediction will most likely also have to be different.
# We would need to take the output of `lgb_model` and use it as an input to the `cb_model`.
#
# Below is a function that captures this ensemble prediction.

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

from mlod.models import Model
from mlod.preprocessors import PreProcessor
from typing import Tuple

import logging
logger = logging.getLogger('mlod')

class EnsemblePredictor:
    def __init__(self, 
                 trained_lgb_model: Model, 
                 cv_trained_cb_model: Model, 
                 lgb_pp_opts: Tuple[PreProcessor, dict], 
                 cb_pp_opts: Tuple[PreProcessor, dict]):
        
        # Checks if the models are trained
        assert trained_lgb_model.model is not None, "the lgb model is not trained"
        assert cv_trained_cb_model.is_cv_trained, "the cb model needs to be trained by cross validation"
        
        self.lgb = trained_lgb_model
        self.cb = cv_trained_cb_model
        
        # load up the preprocessor and config used in LGB model
        lgb_pp, lgp_opts = lgb_pp_opts
        self.lgb_pp = lgb_pp
        self.lgp_opts = lgp_opts
        
        # load up the preprocessor and config used in CatBoost model
        cb_pp, cb_opts = cb_pp_opts
        self.cb_pp = cb_pp
        self.cb_opts = cb_opts
        
    def predict(self, x: pd.DataFrame) -> np.ndarray:
        
        # pre-process like lgb
        x_out_lgb = self.lgb_pp.process(x.copy(), test=True, **self.lgp_opts)
        x_ids = x_out_lgb.pop('ID')
        
        # pre-process like cb
        x_out_cb = self.cb_pp.process(x.copy(), test=True, **self.cb_opts)
        
        logger.info('Making prediction using base model')
        # output for the lgb + merge with x_out_cb
        to_merge = pd.DataFrame.from_dict({ 'ID': x_ids, 'oof': self.lgb.predict(x_out_lgb) })
        
        # mean merge the values
        to_merge = to_merge.groupby('ID').mean()
        x_out_cb = x_out_cb.join(to_merge, on='ID')
        
        # remove ID col + empty unneeded data
        del x_out_cb['ID']
        del to_merge
        
        # store the list of predictions
        ls_preds = []
        
        logger.info('Making prediction using each %d cv models' % len(self.cb.cv_models))
        # get the models used in the cross validations
        for cv_model in tqdm(self.cb.get_cv_models()):
            # make prediction using combined values with the cb model
            pred = cv_model.predict(x_out_cb)
            ls_preds.append(pred)
        
        # compute the mean of the predictions of 
        #  the cross validation models
        return np.mean(ls_preds, 0)

# %% [markdown]
# Using this `EnsemblePredictor` and saving predictions

# %%
import numpy as np
from mlod.file_utils import PredictionStorage

# Building the ensemble predictor
predictor = EnsemblePredictor(
                    lgb_model, 
                    cb_model, 
                    (mlod_preprocessor, mlod_pp_opts),
                    (airqo_preprocessor, airqo_pp_opts)
                )

y_test = predictor.predict(test_df)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 5035/5035 [00:03<00:00, 1531.09it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:03<00:00,  1.23s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 121/121 [00:02<00:00, 55.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 28.83it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:02<00:00,  2.71it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 113.42it/s]

# %%
# Store the results for submission
mean_rmse = np.mean([cb_eval_out['rmse'], lgb_eval_out['rmse']])

out_df = pd.DataFrame.from_dict(dict(ID=TEST_IDS.values, target=y_test)).set_index('ID')
out_df.to_csv(f'./airqo_sub{mean_rmse}.csv')

# %% [markdown]
# The file to upload should be name `airqo_subXXX.csv`. The values in XXX, is a way for us to keep tabs on training steps with what rmse produces what results.
# Its also an indicator of ensemble overfitting
